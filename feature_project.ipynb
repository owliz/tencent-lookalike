# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 0. Basics
# **相似人群拓展（Lookalike)**
# 基于广告主提供的一个种子人群（又称为种子包），自动计算出与之相似的人群（称为扩展人群）
# **种子包**
# 广告主提供的种子人群

# %% [markdown]
# # 1. Data Analysis

# %% [markdown]
# uid, aid, 用户特征和广告特征 都被加密

# %% [markdown]
# ### 1. userFeature.data
# 海量用户特征
# 每行为一个用户的特征数据，特征组以“|”隔开，未知值为0
# **每个用户被记录的特征数量不同**
#
# **具体特征解释：**
# LBS:地理位置
# interset(interest1-5):兴趣id
# keyword(kw1, kw2, kw3): 比interest更具体的兴趣关键词
# appIdInstall：近期安装app
# appIdAction：用户常用app
# topic:LDA挖掘的用户喜好主题
# ct：上网连接类型(WIFI/2G/3G/4G)
# os:操作系统（Android/IOS）
# carrier：移动运营商（移动/联通/电信/其他）

# %%
with open('userFeature.data','r') as f:
    for i in range(10):
        line = f.readline()
        print(line)
# Out:
# uid 26325489|age 4|gender 2|marriageStatus 11|education 7|consumptionAbility 2|LBS 950|interest1 93 70 77 86 109 47 75 69 45 8 29 49 83 6 46 36 11 44 30 118 76 48 28 106 59 67 41 114 111 71 9|interest2 46 19 13 29|interest5 52 100 72 131 116 11 71 12 8 113 28 73 6 132 99 76 46 62 121 59 129 21 93|kw1 664359 276966 734911 103617 562294|kw2 11395 79112 115065 77033 36176|topic1 9826 105 8525 5488 7281|topic2 9708 5553 6745 7477 7150|ct 3 1|os 2|carrier 1
#
# uid 1184123|age 2|gender 1|marriageStatus 5 13|education 2|consumptionAbility 1|LBS 803|interest1 75 29|interest2 33|kw1 338851 361151 542834 496283 229952|kw2 80263 39618 53539 180 38163|topic1 4391 9140 5669 1348 4388|topic2 9401 7724 1380 8890 7153|ct 3 1|os 1|carrier 1
#
# uid 76072711|age 1|gender 1|marriageStatus 13 10|education 5|consumptionAbility 1|LBS 927|interest1 70 12 28 106 59 49 41 6 42 115 35 116 36 11 96|interest2 51 22 79 81 70 6 21 4 41 35|interest5 77 72 80 116 101 13 1 109 8 50 6 42 76 9 46 36 58 64 85 103 131 11 79 48 29 113 69 89 121 59 24 18 60 129 93 54|kw1 746140 695808 126355 771775 411511|kw2 105115 71378 41409 74061 44005|topic1 1502 5488 9826 2187 8088|topic2 5005 9154 2756 5612 4209|ct 3 1|os 1|carrier 3
#
# uid 63071413|age 4|gender 1|marriageStatus 11|education 7|consumptionAbility 1|LBS 486|interest1 93 70 77 47 76 75 69 29 59 49 122 42 46 23 17 56 62 36 78 11 54 65|interest2 24 70 19 13 30 10|interest5 100 80 92 37 116 13 47 4 71 8 50 28 98 115 6 42 99 76 27 9 75 20 46 57 84 64 68 35 56 103 21 40 52 131 19 5 121 74 59 10 25 129 22 93|kw1 283399 402245 734509 654027 32061|kw2 74010 32918 67882 116802 20957|topic1 1619 7342 3064 9213 8525|topic2 810 2438 5659 1844 9262|ct 1 3|os 1 2|carrier 3
#
# uid 81294159|age 5|gender 1|marriageStatus 11|education 6|consumptionAbility 2|LBS 112|interest1 75 29 49 122 36 11|interest5 131 116 13 8 6 132 42 9 59 18 58 64 129 103|kw1 562294 157603 589706 657719 495672|kw2 62764 97803 89066 55545 74061|topic1 477 9826 5808 644 2747|topic2 5483 2199 5424 1511 7751|ct 3 1 4 2|os 1|carrier 3
#
# uid 26419924|age 1|gender 1|marriageStatus 10|education 2|consumptionAbility 0|LBS 589|kw2 18185 117462 75928 88141 40888|topic2 7043 7202 9227 5316 46|ct 0|os 0|carrier 0
#
# uid 3467967|age 4|gender 1|marriageStatus 15|education 7|consumptionAbility 1|LBS 244|interest1 70 76 106 36 11|interest2 24 30|interest5 52 72 131 37 47 79 71 8 113 50 16 6 76 46 74 10 38 93|kw1 518300 122999 682774 268663 378773|kw2 52864 461 12933 35229 51399|topic1 4626 3657 3199 3159 1705|topic2 5115 296 598 986 5791|ct 1 3|os 1|carrier 2
#
# uid 54125482|age 5|gender 1|marriageStatus 5 13|education 2|consumptionAbility 1|LBS 464|interest1 93 70 77 47 75 69 29 49 27 6 53 19 46 56 36 11 54 107 76 59 114 71 17 9 116|interest2 9 21|interest5 72 92 116 13 47 78 71 8 30 50 28 6 42 76 27 9 46 94 58 122 64 35 103 52 131 132 89 62 121 23 74 59 118 129 100 80 37 86 111 20 75 56 114 40 17 61 41 24 60 10 96 93|kw1 704724 593038 664919 542509 236956|kw2 11395 79112 61483 17460 105942|topic1 114 4305 8190 459 1471|topic2 7753 5641 8445 1460 5532|ct 1 3|os 1|carrier 3|house 1
#
# uid 29339838|age 5|gender 1|marriageStatus 11|education 6|consumptionAbility 1|LBS 585|interest1 93 70 118 109 1 76 69 102 28 8 59 49 6 18 39 46 116 36 11 44|interest2 47 73 53 46 4 48 29|interest5 100 72 29 28 20 46|kw1 727276 281795 754537 459430 661396|kw2 28206 72531 94533 45366 59167|topic1 7674 1607 9187 9826 2506|topic2 2200 1217 856 9454 4668|ct 3 1|os 1|carrier 1
#
# uid 3741280|age 1|gender 2|marriageStatus 10|education 7|consumptionAbility 1|LBS 705|interest1 70 76|interest2 47 31 32 44|interest5 77 100 72 92 116 47 109 8 50 86 28 6 42 99 76 27 20 46 58 64 40 52 131 11 107 79 69 41 132 19 5 121 59 118 10 129 93|kw1 279516 454738 497578 469468 196179|kw2 38442 28044 104780 12677 34525|topic1 6989 8567 4209 7684 2281|topic2 6329 9435 3730 80 718|ct 3 1|os 2|carrier 1|house 1

# %% [markdown]
# ### 2. train.csv
# aid 唯一标识一个广告，uid 唯一标识一个用户
# 样本 label 的取值为 +1 或 -1，其中 +1 表示种子用户，-1 表示非种子用户

# %%
df1 = pd.read_csv('train.csv')
df1.head()
# Out:
#     aid       uid  label
# 0   699  78508957     -1
# 1  1991   3637295     -1
# 2  1119  19229018     -1
# 3  2013  79277120     -1
# 4   692  41528441     -1

# %%
df1.describe()
# Out:
#                 aid           uid         label
# count  8.798814e+06  8.798814e+06  8.798814e+06
# mean   1.044592e+03  4.126560e+07 -9.040868e-01
# std    6.138768e+02  2.383198e+07  4.273488e-01
# min    6.000000e+00  2.000000e+00 -1.000000e+00
# 25%    5.190000e+02  2.061748e+07 -1.000000e+00
# 50%    1.107000e+03  4.127522e+07 -1.000000e+00
# 75%    1.530000e+03  6.190352e+07 -1.000000e+00
# max    2.216000e+03  8.254290e+07  1.000000e+00

# %% [markdown]
# ### 3. test1.csv
# aid 唯一标识一个广告，uid 唯一标识一个用户

# %%
df2 = pd.read_csv('test1.csv')
df2.head()
# Out:
#     aid       uid
# 0  2118  64355836
# 1   692  45051997
# 2   692  10869198
# 3  1918  75929554
# 4  1596   5790162

# %%
df2.columns
# Out:
# Index(['aid', 'uid'], dtype='object')

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=2265989, step=1)

# %%
df2.describe()
# Out:
#                 aid           uid
# count  2.265989e+06  2.265989e+06
# mean   1.044734e+03  4.127397e+07
# std    6.138297e+02  2.383690e+07
# min    6.000000e+00  8.000000e+00
# 25%    5.190000e+02  2.063520e+07
# 50%    1.107000e+03  4.127856e+07
# 75%    1.530000e+03  6.192064e+07
# max    2.216000e+03  8.254288e+07

# %% [markdown]
# #### 有重复uid

# %%
new_df2 = df2.drop_duplicates(subset=['uid'],keep='first')

# %%
new_df2.describe()
# Out:
#                 aid           uid
# count  2.195951e+06  2.195951e+06
# mean   1.042024e+03  4.127717e+07
# std    6.123307e+02  2.383508e+07
# min    6.000000e+00  8.000000e+00
# 25%    5.160000e+02  2.064691e+07
# 50%    1.057000e+03  4.128092e+07
# 75%    1.530000e+03  6.192491e+07
# max    2.216000e+03  8.254288e+07

# %% [markdown]
# ### 4. adFeature.csv
# 账户结构分为四级：账户——推广计划——广告——素材
# **具体特征解释：**
# aid：广告id，primarykey
# advertiserId：账户对应广告主
# campaignId：推广计划（广告集合）
# creativeId：素材id
# creativeSize：素材大小
# adCatergoryId：使用广告分类体系对广告分类
# productId：待推广商品id
# productType：投放目标对应的商品类型

# %%
df3 = pd.read_csv('adFeature.csv')
df3.head()
# Out:
#     aid  advertiserId  campaignId  creativeId  creativeSize  adCategoryId  \
# 0   177          8203       76104     1500666            59           282
# 1  2050         19441      178687      245165            53             1
# 2  1716          5552      158101     1080850            35            27
# 3   336           370        4833      119845            22            67
# 4   671         45705      352827      660519            42            67
#
#    productId  productType
# 0          0            6
# 1          0            6
# 2        113            9
# 3        113            9
# 4          0            4

# %%
df3.describe()
# Out:
#                aid   advertiserId     campaignId    creativeId  creativeSize  \
# count   173.000000     173.000000     173.000000  1.730000e+02    173.000000
# mean   1140.364162   13229.202312  159044.612717  9.388567e+05     50.364162
# std     658.957025   23033.243589  184836.397583  5.211123e+05     24.827317
# min       6.000000      60.000000      80.000000  5.977000e+03     20.000000
# 25%     562.000000     702.000000   31020.000000  4.924840e+05     35.000000
# 50%    1171.000000    7229.000000   76104.000000  9.818220e+05     42.000000
# 75%    1728.000000   11487.000000  209098.000000  1.383456e+06     59.000000
# max    2216.000000  158679.000000  766460.000000  1.806760e+06    109.000000
#
#        adCategoryId     productId  productType
# count    173.000000    173.000000   173.000000
# mean      57.335260   2559.277457     7.346821
# std       62.197012   5570.602765     2.827595
# min        1.000000      0.000000     4.000000
# 25%       21.000000      0.000000     4.000000
# 50%       27.000000      0.000000     6.000000
# 75%       67.000000   3733.000000    11.000000
# max      282.000000  28986.000000    11.000000

# %% [markdown]
# ### 5. submission.csv
# 提交结果
# 每行记录表示该用户在该种子包中的得分
# score 字段有效数字不得超过 8 位
# aid,uid,score
# 100,10000000,0.62124588
